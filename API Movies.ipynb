# %%
import numpy as np
import pandas as pd
import requests
import json

# %%
url1= "https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1"

# %%
url1= requests.get(url1).json()
print (url1)
# Out:
# {'page': 1, 'total_results': 6358, 'total_pages': 318, 'results': [{'popularity': 13.871, 'vote_count': 2104, 'video': False, 'poster_path': '/2CAL2433ZeIihfX1Hb2139CX0pW.jpg', 'id': 19404, 'adult': False, 'backdrop_path': '/mMaxGuQKuH4WUHBwUNhJOetDYE9.jpg', 'original_language': 'hi', 'original_title': 'दिलवाले दुल्हनिया ले जायेंगे', 'genre_ids': [35, 18, 10749], 'title': 'Dilwale Dulhania Le Jayenge', 'vote_average': 8.9, 'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.', 'release_date': '1995-10-20'}, {'popularity': 29.365, 'vote_count': 13686, 'video': False, 'poster_path': '/9O7gLzmreU0nGkIB6K3BsJbzvNv.jpg', 'id': 278, 'adult': False, '
# ...

# %%
Data1=pd.DataFrame(url1['results'])

# %%
Data1
# Out:
#     adult                     backdrop_path              genre_ids      id  \
# 0   False  /mMaxGuQKuH4WUHBwUNhJOetDYE9.jpg        [35, 18, 10749]   19404
# 1   False  /j9XKiZrVeViAixVRzCta7h1VU9W.jpg               [80, 18]     278
# 2   False  /6xKCYgH16UuwEGAyroLU6p8HLIn.jpg               [80, 18]     238
# 3   False  /cM0pnzCF6T7u1AAEYgyCG6Sua6k.jpg           [35, 18, 53]  496243
# 4   False  /nvsdKYPKwf51EAgC0xLJMB9kUZM.jpg        [16, 18, 10749]  372058
# 5   False  /cTNYRUTXkBgPH3wP3kmPUB5U6dA.jpg        [18, 36, 10752]     424
# 6   False  /gLbBRyS7MBrmVUNce91Hmx9vzqI.jpg               [80, 18]     240
# 7   False  /mnpRKVSXBX6jb56nabvmGKA0Wig.jpg        [16, 14, 10751]     129
# 8   False   /Rlt20sEbOQKPVjia7lUilFm49W.jpg           [14, 18, 80]     497
# 9   False  /bORe0eI72D874TMawOOFvqWS6Xe.jpg               [35, 18]     637
# 10  False  /4cDFJr4HnXN5AdPw4AKrmLlMWdO.jpg               [80, 53]     680
# ...

# %%
Data1.columns
# Out:
# Index(['adult', 'backdrop_path', 'genre_ids', 'id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'release_date', 'title', 'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
Data1.drop(['adult','backdrop_path','genre_ids','original_language','original_title','poster_path','vote_count','video'], axis=1, inplace=True)

# %%
Data1
# Out:
#         id                                           overview  popularity  \
# 0    19404  Raj is a rich, carefree, happy-go-lucky second...      13.871
# 1      278  Framed in the 1940s for the double murder of h...      29.365
# 2      238  Spanning the years 1945 to 1955, a chronicle o...      26.759
# 3   496243  All unemployed, Ki-taek's family takes peculia...      38.010
# 4   372058  High schoolers Mitsuha and Taki are complete s...      21.771
# 5      424  The true story of how businessman Oskar Schind...      27.675
# 6      240  In the continuing saga of the Corleone crime f...      23.360
# 7      129  A young girl, Chihiro, becomes trapped in a st...      31.056
# 8      497  A supernatural tale set on death row in a Sout...      19.512
# 9      637  A touching story of an Italian book seller of ...      22.715
# 10     680  A burger-loving hit man, his philosophical par...      34.288
# 11  324857  Miles Morales is juggling his life between bei...      53.028
# ...

# %%
url2="https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=2"
url3="https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=3"
url4="https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=4"
url5="https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=5"
url6="https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=6"
url7="https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=7"
url8="https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=8"
url9="https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=9"
url10="https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=10"

# %%
url2= requests.get(url2).json()
url3= requests.get(url3).json()
url4= requests.get(url4).json()
url5= requests.get(url5).json()
url6= requests.get(url6).json()
url7= requests.get(url7).json()
url8= requests.get(url8).json()
url9= requests.get(url9).json()
url10= requests.get(url10).json()

# %%
Data2=pd.DataFrame(url2['results'])
Data3=pd.DataFrame(url3['results'])
Data4=pd.DataFrame(url4['results'])
Data5=pd.DataFrame(url5['results'])
Data6=pd.DataFrame(url6['results'])
Data7=pd.DataFrame(url7['results'])
Data8=pd.DataFrame(url8['results'])
Data9=pd.DataFrame(url9['results'])
Data10=pd.DataFrame(url10['results'])

# %%
Data2.drop(['adult','backdrop_path','genre_ids','original_language','original_title','poster_path','vote_count','video'], axis=1, inplace=True)
Data3.drop(['adult','backdrop_path','genre_ids','original_language','original_title','poster_path','vote_count','video'], axis=1, inplace=True)
Data4.drop(['adult','backdrop_path','genre_ids','original_language','original_title','poster_path','vote_count','video'], axis=1, inplace=True)
Data5.drop(['adult','backdrop_path','genre_ids','original_language','original_title','poster_path','vote_count','video'], axis=1, inplace=True)
Data6.drop(['adult','backdrop_path','genre_ids','original_language','original_title','poster_path','vote_count','video'], axis=1, inplace=True)
Data7.drop(['adult','backdrop_path','genre_ids','original_language','original_title','poster_path','vote_count','video'], axis=1, inplace=True)
Data8.drop(['adult','backdrop_path','genre_ids','original_language','original_title','poster_path','vote_count','video'], axis=1, inplace=True)
Data9.drop(['adult','backdrop_path','genre_ids','original_language','original_title','poster_path','vote_count','video'], axis=1, inplace=True)
Data10.drop(['adult','backdrop_path','genre_ids','original_language','original_title','poster_path','vote_count','video'], axis=1, inplace=True)

# %%
Data2
# Out:
#         id                                           overview  popularity  \
# 0      769  The true story of Henry Hill, a half-Irish, ha...      24.964
# 1      311  A former Prohibition-era Jewish gangster retur...      16.142
# 2    11216  A filmmaker recalls his childhood, when he fel...      14.203
# 3      346  A samurai answers a village's request for prot...      16.423
# 4      510  While serving time for insanity at a state men...      22.644
# 5    40096  The lively João Grilo and the sly Chicó are po...       7.400
# 6      901  City Lights is the first silent film that Char...      11.549
# 7   244786  Under the direction of a ruthless instructor, ...      29.476
# 8    12477  In the final months of World War II, 14-year-o...       0.600
# 9      598  Cidade de Deus is a shantytown that started du...      16.514
# 10     599  A hack screenwriter writes a screenplay for a ...      13.023
# 11  432517  Long buried secrets finally come to light as s...      11.169
# ...

# %%
Data3
# Out:
#         id                                           overview  popularity  \
# 0   313106  In 2013, something terrible is awakening in Lo...       8.534
# 1   299534  After the devastating events of Avengers: Infi...     108.459
# 2    11659  Spanning four decades, from the chaotic 1960s ...       5.040
# 3      128  Ashitaka, a prince of the disappearing Ainu tr...      21.182
# 4      207  At an elite, old-fashioned boarding school in ...      16.859
# 5    20914  Like in many other Monicelli movies, the main ...       5.947
# 6   265177  A peculiar neighbor offers hope to a recent wi...       9.919
# 7   290098  1930s Korea, in the period of Japanese occupat...      20.702
# 8    10376  The story of a virtuoso piano player who lives...       9.229
# 9      797  A young nurse, Alma, is put in charge of Elisa...      12.190
# 10     895  An expansive Russian drama, this film focuses ...       9.936
# 11     567  Professional photographer L.B. "Jeff" Jeffries...      17.620
# ...

# %%
Data4
# Out:
#         id                                           overview  popularity  \
# 0      120  Young hobbit Frodo Baggins, after inheriting a...      32.162
# 1   490132  Tony Lip, a bouncer in 1962, is hired to drive...      27.443
# 2   398818  Elio Perlman is spending the summer with his f...      25.775
# 3    24188  Roberto, a shy law student in Rome, meets Brun...       6.540
# 4     3082  The Tramp struggles to live in modern industri...      11.384
# 5    27205  Cobb, a skilled thief who commits corporate es...      39.292
# 6      274  Clarice Starling is a top student at the FBI's...       3.998
# 7   299536  As the Avengers and their allies have continue...      75.798
# 8      121  Frodo and Sam are trekking to Mordor to destro...      28.464
# 9   378064  Shouya Ishida starts bullying the new girl in ...      13.155
# 10   12493  An executive of a shoe company becomes a victi...       6.431
# 11     335  A widow whose land and life are in danger as t...      16.082
# ...

# %%
Data5
# Out:
#         id                                           overview  popularity  \
# 0      105  Eighties teenager Marty McFly is accidentally ...      24.953
# 1   339877  The film brings the paintings of Vincent van G...      12.433
# 2   406997  The story of August Pullman – a boy with facia...      20.465
# 3      284  Bud Baxter is a minor clerk in a huge New York...      12.321
# 4       28  At the height of the Vietnam war, Captain Benj...      38.805
# 5     5156  Antonio, an unemployed man in the depressed po...       9.845
# 6      426  A retired San Francisco detective suffering fr...      14.186
# 7   470044  Raised in a poverty-stricken slum, a 16-year-o...      15.404
# 8      670  With no clue how he came to be imprisoned, dru...      18.403
# 9     1585  A holiday favourite for generations...  George...      17.408
# 10     422  Guido Anselmi, a film director, finds himself ...      14.064
# 11     490  When disillusioned Swedish knight Antonius Blo...      11.161
# ...

# %%
Data6
# Out:
#         id                                           overview  popularity  \
# 0       11  Princess Leia is captured and held hostage by ...      41.525
# 1       77  Leonard Shelby is tracking down the man who ra...      16.139
# 2      185  In a near-future Britain, young Alexander DeLa...      20.275
# 3      239  Two musicians witness a mob hit and struggle t...      15.107
# 4      996  A rich woman and a calculating insurance agent...      15.110
# 5      548  Brimming with action while incisively examinin...      12.261
# 6    92321  One hot summer day a little girl gets lost in ...       0.600
# 7    19542  In this classic drama, Vicky Page is an aspiri...       9.229
# 8   399106  A mother bird tries to teach her little one ho...       8.450
# 9    10494  A retired pop singer turned actress' sense of ...      12.789
# 10     103  A mentally unstable Vietnam War veteran works ...      19.711
# 11  354912  Despite his family’s baffling generations-old ...      28.425
# ...

# %%
Data7
# Out:
#         id                                           overview  popularity  \
# 0   449176  Everyone deserves a great love story. But for ...      18.692
# 1      833  When elderly pensioner Umberto Domenico Ferrar...       7.160
# 2    28978  Charlie, a wandering tramp, becomes a circus h...       7.653
# 3     8392  Two sisters move to the country with their fat...      31.769
# 4    50014  Aibileen Clark is a middle-aged African-Americ...      13.497
# 5      832  In this classic German thriller, Hans Beckert,...      11.168
# 6      872  In 1927 Hollywood, a silent film production co...      12.646
# 7      961  During America’s Civil War Union spies steal e...      11.461
# 8      654  Terry Malloy dreams about being a prize fighte...      11.173
# 9     1396  A dying man in his forties recalls his childho...      10.030
# 10   16869  In Nazi-occupied France during World War II, a...      26.012
# 11     655  A man wanders out of the desert not knowing wh...      12.752
# ...

# %%
Data8
# Out:
#         id                                           overview  popularity  \
# 0   149871  Found inside a shining stalk of bamboo by an o...       9.787
# 1      147  For young Parisian boy Antoine Doinel, life is...      11.526
# 2     3090  Fred C. Dobbs and Bob Curtin, both down on the...      16.176
# 3    29264  After a lavish dinner party, the guests find t...       9.200
# 4      289  In Casablanca, Morocco in December 1941, a cyn...      26.053
# 5   237791  Leonardo is a blind teenager dealing with an o...       6.996
# 6      100  A card shark and his unwillingly-enlisted frie...       8.314
# 7   498249  Wael, a former street child, makes a living fr...       5.827
# 8    10242  Two aging film actresses live as virtual reclu...       9.622
# 9    11645  With Ran, legendary director Akira Kurosawa re...      12.310
# 10     857  As U.S. troops storm the beaches of Normandy, ...      22.179
# 11   11324  World War II soldier-turned-U.S. Marshal Teddy...      19.588
# ...

# %%
Data9
# Out:
#         id                                           overview  popularity  \
# 0    11712  Toshiro Mifune swaggers and snarls to brillian...       8.224
# 1     7345  Ruthless silver miner, turned oil prospector, ...      15.052
# 2    11104  Two melancholic Hong Kong policemen fall in lo...      13.016
# 3   491480  Against all the odds, a thirteen year old boy ...       9.522
# 4    46738  A mother's last wishes send twins Jeanne and S...      10.076
# 5    11423  1986 Gyunggi Province. The body of a young wom...      12.416
# 6     9277  Set in the 1930s this intricate caper deals wi...      11.368
# 7   160885                                                          5.653
# 8   205596  Based on the real life story of legendary cryp...      30.814
# 9      582  A tragic love story set in East Berlin with th...      11.133
# 10    1092  In postwar Vienna, Austria, Holly Martins, a w...      15.271
# 11     348  During its return to the earth, commercial spa...      28.754
# ...

# %%
Data10
# Out:
#         id                                           overview  popularity  \
# 0      387  A German submarine hunts allied ships during t...      13.485
# 1   424694  Singer Freddie Mercury, guitarist Brian May, d...      37.741
# 2      204  In the South American jungle, supplies of nitr...      11.598
# 3    32085  Young Vincent Malloy dreams of being just like...       4.720
# 4      821  In 1947, four German judges who served on the ...       8.921
# 5   103663  A teacher lives a lonely life, all the while s...      12.127
# 6     7347  In 1997, before the visit of the pope to Rio d...      12.066
# 7       62  Humanity finds a mysterious object buried bene...      26.074
# 8      110  Part-time model Valentine meets a retired judg...      11.520
# 9      521  An ex-tennis pro carries out a plot to have hi...      21.033
# 10   37165  Truman Burbank is the star of "The Truman Show...      16.992
# 11  120467  The Grand Budapest Hotel tells of a legendary ...      20.558
# ...

# %%
Data=pd.concat([Data1, Data2, Data3, Data4, Data5, Data6, Data7, Data8, Data9, Data10])

# %%
Data
# Out:
#         id                                           overview  popularity  \
# 0    19404  Raj is a rich, carefree, happy-go-lucky second...      13.871
# 1      278  Framed in the 1940s for the double murder of h...      29.365
# 2      238  Spanning the years 1945 to 1955, a chronicle o...      26.759
# 3   496243  All unemployed, Ki-taek's family takes peculia...      38.010
# 4   372058  High schoolers Mitsuha and Taki are complete s...      21.771
# 5      424  The true story of how businessman Oskar Schind...      27.675
# 6      240  In the continuing saga of the Corleone crime f...      23.360
# 7      129  A young girl, Chihiro, becomes trapped in a st...      31.056
# 8      497  A supernatural tale set on death row in a Sout...      19.512
# 9      637  A touching story of an Italian book seller of ...      22.715
# 10     680  A burger-loving hit man, his philosophical par...      34.288
# 11  324857  Miles Morales is juggling his life between bei...      53.028
# ...

# %%
data.to_csv(r'C:\Users\Roumyak Biswas\API-Movies\data.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-ea764c656edd> in <module>()
# ----> 1 data.to_csv(r'C:\Users\Roumyak Biswas\API-Movies\data.csv', index=False)
#
# NameError: name 'data' is not defined
